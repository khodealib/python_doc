# %% [markdown]
# <div dir="rtl" style="font-family: Vazirmatn">
# <bold style="text-align: center;"><p>استفاده از مفسر پایتون</p></bold>
# <p><bold>نصب و راه‌اندازی پایتون</bold></p>
# <p>برای نصب و راه‌اندازی پایتون، می‌توانید از لینک‌های زیر استفاده کنید (بهتره که از نسخه ۳.۹ استفاده کنید).</p>
# <p dir="ltr">
#     <ul>
#             <li><a href="https://linuxize.com/post/how-to-install-python-3-9-on-ubuntu-20-04/">Linux</a></li>
#             <li><a href="https://python.tutorials24x7.com/blog/how-to-install-python-3-9-on-windows-10">Windows</a></li>
#             <li><a href="MacOS">MacOS</a></li>
#     </ul>
# </p>
#
# <p>پس از نصب پایتون با نوشتن دستور زیر در محیط متنی هر سیستم‌عاملی (ترمینال در لینوکس و مک، خط فرمان در ویندوز) مفسر پایتون اجرا می‌شود.</p>
# </div>

# %%
python3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/khodealib/python_doc/introduction.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/khodealib/python_doc/introduction.ipynb#ch0000001?line=0'>1</a> python3
#
# NameError: name 'python3' is not defined
